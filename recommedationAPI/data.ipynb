# %%
import pandas as pd

# %%
content = pd.read_csv("resource/contents_meta_data_final.csv")

# %%
content
# Out:
#               name  year                genres        country   runtime  \
# 0          #리얼리티하이  2017                  코미디              미국  1시간 39분
# 1            #살아있다  2020                  드라마              한국  1시간 38분
# 2           #셀피 69  2016           액션 코미디 로맨스            루마니아  1시간 56분
# 3           #아이엠히어  2019              로맨스 코미디        프랑스  벨기에  1시간 37분
# 4           '신'데렐라  2022           코미디 가족 뮤지컬              미국  1시간 52분
# ...            ...   ...                   ...            ...       ...
# 9615          힌터랜드  2021   범죄 드라마 역사 미스터리 스릴러    오스트리아  룩셈부르크  1시간 38분
# 9616       힐빌리의 노래  2020                  드라마              미국  1시간 55분
# 9617        힐즈 아이즈  2006           공포 드라마 스릴러              미국  1시간 47분
# 9618     힘내세요, 병헌씨  2012              드라마 코미디              한국  1시간 34분
# 9619  힘을 내요, 미스터 리  2018              코미디 드라마              한국  1시간 51분
#
#      age_rating                                           overview  \
# ...
